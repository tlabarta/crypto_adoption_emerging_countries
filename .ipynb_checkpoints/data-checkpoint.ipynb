# %%
import numpy as np
import pandas as pd

# %%
df_crypto_adoption = pd.read_csv("../crypto_adoption_emerging_countries/input/Crypto Adoption.csv", sep=";", index_col="Country")
df_crypto_adoption
# Out:
#           Index score   Overall index ranking  On-chain value received  \
# Country
# Vietnam           1.00                      1                        4
# India             0.37                      2                        2
# Pakistan          0.36                      3                       11
# Ukraine           0.29                      4                        6
# Kenya             0.28                      5                       41
#
#           On-chain retail value received  P2P exchange trade volume
# Country
# Vietnam                                2                          3
# India                                  3                         72
# Pakistan                              12                          8
# Ukraine                                5                         40
# Kenya                                 28                          1

# %%
df_rural_population = pd.read_csv("../crypto_adoption_emerging_countries/input/Rural Population.csv", index_col="Country Name")
df_rural_population = df_rural_population.loc[:,["2020"]].rename({"2020": "Rural population (% of total population)"}, axis="columns")
df_rural_population
# Out:
#                              Rural population (% of total population)
# Country Name
# Aruba                                                       56.303000
# Africa Eastern and Southern                                 63.216694
# Afghanistan                                                 73.974000
# Africa Western and Central                                  52.151375
# Angola                                                      33.175000
# ...                                                               ...
# Kosovo                                                            NaN
# Yemen, Rep.                                                 62.092000
# South Africa                                                32.646000
# Zambia                                                      55.371000
# Zimbabwe                                                    67.758000
#
# [266 rows x 1 columns]

# %%
df_crypto_all = pd.merge(df_crypto_adoption, df_rural_population, left_index=True, right_index=True)
df_crypto_all
# Out:
#           Index score   Overall index ranking  On-chain value received  \
# Vietnam           1.00                      1                        4
# India             0.37                      2                        2
# Pakistan          0.36                      3                       11
# Ukraine           0.29                      4                        6
# Kenya             0.28                      5                       41
#
#           On-chain retail value received  P2P exchange trade volume  \
# Vietnam                                2                          3
# India                                  3                         72
# Pakistan                              12                          8
# Ukraine                                5                         40
# Kenya                                 28                          1
#
#           Rural population (% of total population)
# Vietnam                                     62.660
# ...

# %%
df_financial_incl = pd.read_csv("../crypto_adoption_emerging_countries/input/Financial Inclusion.csv", index_col="Country Name")
df_financial_incl
# Out:
#              Country Code                                        Series Name  \
# Country Name
# Afghanistan           AFG                                Account (% age 15+)
# Afghanistan           AFG          Account, income, poorest 40% (% ages 15+)
# Afghanistan           AFG                         Account, rural (% age 15+)
# Afghanistan           AFG  Borrowed any money using a mobile money accoun...
# Afghanistan           AFG  Borrowed any money from a formal financial ins...
# ...                   ...                                                ...
# World                 WLD                     Owns a credit card (% age 15+)
# World                 WLD              Owns a credit card, rural (% age 15+)
# World                 WLD              Received digital payments (% age 15+)
# World                 WLD       Received digital payments, rural (% age 15+)
# World                 WLD  Received digital payments, income, poorest 40%...
#
# ...

# %%
#Note to Tobi: Review statistical tests before finalizing table format!!!

# %%
df_country_all = pd.read_csv("../crypto_adoption_emerging_countries/input/All Country Data.csv", index_col="Country")
df_country_all
# Out:
#                  C     CC     RQ     D     EF    HDI      E      G  CPI  \
# Country
# Afghanistan  0.000   6.73  10.10  2.85  51.50  0.511  0.414  29.70   16
# Albania      0.010  33.17  63.94  5.89  66.50  0.795  0.746  33.20   35
# Algeria      0.000  29.33   7.69  4.01  46.20  0.748  0.672  27.60   35
# Angola       0.016  13.94  16.35  3.72  50.60  0.581  0.500  51.30   26
# Argentina    0.174  53.37  33.65  7.02  52.20  0.845  0.855  41.40   45
# ...            ...    ...    ...   ...    ...    ...    ...    ...  ...
# Venezuela    0.799   4.33   0.48  2.88  25.90  0.711  0.700  52.15   16
# Vietnam      0.443  34.13  41.83  3.08  55.30  0.704  0.630  35.70   37
# Yemen        0.005   1.92   4.33  1.95  60.85  0.470  0.350  36.70   15
# Zambia       0.051  28.37  31.25  5.09  53.60  0.584  0.557  57.10   34
# Zimbabwe     0.000  10.10   6.25  3.16  40.40  0.571  0.587  44.30   24
#
#                    GDP      N
# Country
# Afghanistan   2542.853  41.77
# ...

# %%
df_crypto_all = df_country_all["C"]
df_crypto_all
# Out:
# Country
# Afghanistan    0.000
# Albania        0.010
# Algeria        0.000
# Angola         0.016
# Argentina      0.174
#                ...
# Venezuela      0.799
# Vietnam        0.443
# Yemen          0.005
# Zambia         0.051
# Zimbabwe       0.000
# Name: C, Length: 137, dtype: float64

# %%
df_hdi_all = df_country_all.loc[:, df_country_all.columns!="C"]
df_hdi_all
# Out:
#                 CC     RQ     D     EF    HDI      E      G  CPI        GDP  \
# Country
# Afghanistan   6.73  10.10  2.85  51.50  0.511  0.414  29.70   16   2542.853
# Albania      33.17  63.94  5.89  66.50  0.795  0.746  33.20   35  14534.109
# Algeria      29.33   7.69  4.01  46.20  0.748  0.672  27.60   35  11894.859
# Angola       13.94  16.35  3.72  50.60  0.581  0.500  51.30   26   7346.304
# Argentina    53.37  33.65  7.02  52.20  0.845  0.855  41.40   45  22997.000
# ...            ...    ...   ...    ...    ...    ...    ...  ...        ...
# Venezuela     4.33   0.48  2.88  25.90  0.711  0.700  52.15   16   7344.079
# Vietnam      34.13  41.83  3.08  55.30  0.704  0.630  35.70   37  10535.168
# Yemen         1.92   4.33  1.95  60.85  0.470  0.350  36.70   15   2056.586
# Zambia       28.37  31.25  5.09  53.60  0.584  0.557  57.10   34   3526.397
# Zimbabwe     10.10   6.25  3.16  40.40  0.571  0.587  44.30   24   2869.348
#
#                  N
# Country
# ...
